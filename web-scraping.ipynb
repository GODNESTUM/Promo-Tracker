# %%
import requests
from bs4 import BeautifulSoup

products=[] #List to store name of the product
prices=[] #List to store price of the product
ratings=[] #List to store rating of the product
url = "https://www.bestsecret.com/new_category.htm?shop=campaign_126984&gender=MALE&c=de&l=en&utm_medium=email&utm_source=daily-newsletter-BASIC&utm_campaign=DE%3a20210830%3aemail%3adaily-newsletter-BASIC%3a0%3a0%3am%3aen%3aTop_Cat_3&utm_content=transaction"
page = requests.get(url)
soup = BeautifulSoup(page.text,"html.parser")
#print(soup.prettify)
# soup.h3["class" == "productTitleName"]

# soup.find_all("a", class_ = "smth") # Use class_ as class is reserved in Python
# def has_six_characters(css_class):
#     return css_class is not None and len(css_class) == 6
# soup.find_all(class_=has_six_characters)

# data_soup.find_all(attrs={"data-foo": "value"})
# # [<div data-foo="value">foo!</div>]

# product_image = soup.find_all(attrs={class_:"span product-container"})
# languages = soup.find_all("a")#, attrs={"language-selection" :"language-options"},limit=20)
languages = soup.select("a[href]")
print("\n")
for language in languages:
    print(language.prettify())
# print(languages[0].parent)

# search = soup.find_all("link")
# #print (search)
# for item in search:
#     # print(item.contents)
#     for child in item.children:
#         print(child)

# python_jobs = results.find_all(
#     "h2", string=lambda text: "python" in text.lower()
# )
# print(len(python_jobs))

# for job_element in python_job_elements:
#     link_url = job_element.find_all("a")[1]["href"]
#     print(f"Apply here: {link_url}\n")

# titles = soup.find("h3", class_="productTitleName")
# print(products.prettify())
# print(titles.prettify())
# driver.get(url)
# content = driver.page_source
# content
# Out:
# <a class="link" href="https://jobs.bestsecret.com/" rel="noopener" target="_blank">
#  Jobs
# </a>
#
# <a class="link cmp-manageconsentbutton hidden" href="javascript:void(0);" target="_self">
#  Cookie settings
# </a>
#
# <a class="link" href="/contact.htm" target="_self">
#  Contact
# </a>
#
# <a class="link" href="/data_protection.htm" target="_self">
#  Privacy Policy
# </a>
#
# <a class="link" href="/terms.htm" rel="noopener" target="_blank">
#  Terms and Conditions
# </a>
#
# <a class="link" href="/imprint.htm" target="_self">
#  Imprint
# </a>
#
# <a class="link" href="https://www.facebook.com/bestsecret" rel="noopener" target="_blank">
#  <i class="icon-footer-facebook">
#  </i>
# </a>
#
# <a class="link" href="http://itunes.apple.com/de/app/bestsecret.com/id475731082" rel="noopener" target="_blank">
#  <i class="icon-footer-apple">
#  </i>
# </a>
#
# <a class="link" href="https://play.google.com/store/apps/details?id=com.bestsecret.main" rel="noopener" target="_blank">
# ...
